# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading and processing data

# %%
def process_data(data):
    process_data = data
    process_data.drop(columns=['P¨roductUrl'])
    return processed_data

# %%
data = pd.read_csv('flipkart_review_data_2022_02.csv')
data = process_data(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19100\3463694791.py in <module>
#       1 data = pd.read_csv('flipkart_review_data_2022_02.csv')
# ----> 2 data = process_data(data)
#
# ~\AppData\Local\Temp\ipykernel_19100\2393612428.py in process_data(data)
#       1 def process_data(data):
#       2     process_data = data
# ----> 3     return processed_data
#
# NameError: name 'processed_data' is not defined

# %%
data
# Out:
#      Unnamed: 0                                         ProductUrl  \
# 0             0  https://www.flipkart.com/lg-108-cm-43-inch-ult...
# 1             1  https://www.flipkart.com/lg-108-cm-43-inch-ult...
# 2             2  https://www.flipkart.com/lg-108-cm-43-inch-ult...
# 3             3  https://www.flipkart.com/lg-108-cm-43-inch-ult...
# 4             5  https://www.flipkart.com/lg-108-cm-43-inch-ult...
# ..          ...                                                ...
# 338         438  https://www.flipkart.com/lg-108-cm-43-inch-ult...
# 339         439  https://www.flipkart.com/lg-108-cm-43-inch-ult...
# 340         440  https://www.flipkart.com/lg-108-cm-43-inch-ult...
# 341         441  https://www.flipkart.com/lg-108-cm-43-inch-ult...
# 342         451  https://www.flipkart.com/lg-108-cm-43-inch-ult...
#
#                                        productTitle productPrice  \
# 0    LG 108 cm (43 inch) Ultra HD (4K) LED Smart TV      ₹36,499
# ...

# %% [markdown]
# # Splitting data

# %% [markdown]
# # Building sentimental analysis model

# %%
def predict_review(review):
    '''Returns a prediction that the review is positive or negative given a review'''
    
    return prediction

# %% [markdown]
# # Training

# %%
train, test =

# %% [markdown]
# # Model performance

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Test

# %%
data = pd.read_html('https://drive.google.com/file/d/17NbKWprVVJhV8tmRsJ_Mdhfayitlfe1d')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4616\1716137185.py in <module>
# ----> 1 data = pd.read_html('https://drive.google.com/file/d/17NbKWprVVJhV8tmRsJ_Mdhfayitlfe1d')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1111     io = stringify_path(io)
#    1112
# -> 1113     return _parse(
#    1114         flavor=flavor,
#    1115         io=io,
#
# ...

# %%
import pandas as pd
url='https://drive.google.com/file/d/17NbKWprVVJhV8tmRsJ_Mdhfayitlfe1d'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4616\2315874351.py in <module>
#       2 url='https://drive.google.com/file/d/17NbKWprVVJhV8tmRsJ_Mdhfayitlfe1d'
#       3 url='https://drive.google.com/uc?id=' + url.split('/')[-2]
# ----> 4 df = pd.read_csv(url)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import pandas as pd

url = 'https://drive.google.com/file/d/17NbKWprVVJhV8tmRsJ_Mdhfayitlfe1d'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4616\285317387.py in <module>
#       3 url = 'https://drive.google.com/file/d/17NbKWprVVJhV8tmRsJ_Mdhfayitlfe1d'
#       4 path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
# ----> 5 df = pd.read_csv(path)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data
# Out:
#     <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="m4dpmE9pJjoAFAmIQ2IVBA">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>flip
# ...

# %%
# 1) TEXTBLOB

def textblob_analyzer(doc):
    txt = TextBlob(doc)
    df = pd.DataFrame(columns=['Sentiment'])
    for i, sentence in enumerate(txt.sentences):
        df = df.append({'Sentiment': sentence.sentiment.polarity}, ignore_index=True)
    return df

blob_neg = textblob_analyzer(neg_text)
blob_pos = textblob_analyzer(pos_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19100\39927107.py in <module>
#       8     return df
#       9
# ---> 10 blob_neg = textblob_analyzer(neg_text)
#      11 blob_pos = textblob_analyzer(pos_text)
#
# ~\AppData\Local\Temp\ipykernel_19100\39927107.py in textblob_analyzer(doc)
#       2
#       3 def textblob_analyzer(doc):
# ----> 4     txt = TextBlob(doc)
#       5     df = pd.DataFrame(columns=['Sentiment'])
#       6     for i, sentence in enumerate(txt.sentences):
#
# NameError: name 'TextBlob' is not defined

# %%
# !pip install vaderSentiment
# Out:
# ...
#   Using cached vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
# ...
#      ---------------------------------------- 62.6/62.6 kB 1.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 96.9/96.9 kB 5.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 61.5/61.5 kB ? eta 0:00:00
# ...
#      -------------------------------------- 123.6/123.6 kB 7.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 157.0/157.0 kB 9.2 MB/s eta 0:00:00
# ...

# %%
# import SentimentIntensityAnalyzer class
# from vaderSentiment.vaderSentiment module.
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
 
# function to print sentiments
# of the sentence.
def sentiment_scores(sentence):
 
    # Create a SentimentIntensityAnalyzer object.
    sid_obj = SentimentIntensityAnalyzer()
 
    # polarity_scores method of SentimentIntensityAnalyzer
    # object gives a sentiment dictionary.
    # which contains pos, neg, neu, and compound scores.
    sentiment_dict = sid_obj.polarity_scores(sentence)
     
    print("Overall sentiment dictionary is : ", sentiment_dict)
    print("sentence was rated as ", sentiment_dict['neg']*100, "% Negative")
    print("sentence was rated as ", sentiment_dict['neu']*100, "% Neutral")
    print("sentence was rated as ", sentiment_dict['pos']*100, "% Positive")
 
    print("Sentence Overall Rated As", end = " ")
 
    # decide sentiment as positive, negative and neutral
    if sentiment_dict['compound'] >= 0.05 :
        print("Positive")
 
    elif sentiment_dict['compound'] <= - 0.05 :
        print("Negative")
 
    else :
        print("Neutral")
 
 
   
# Driver code
if __name__ == "__main__" :
 
    print("\n1st statement :")
    sentence = "Geeks For Geeks is the best portal for \
                the computer science engineering students."
 
    # function calling
    sentiment_scores(sentence)
 
    print("\n2nd Statement :")
    sentence = "study is going on as usual"
    sentiment_scores(sentence)
 
    print("\n3rd Statement :")
    sentence = "I am very sad today."
    sentiment_scores(sentence)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19100\2954754370.py in <module>
#       1 # import SentimentIntensityAnalyzer class
#       2 # from vaderSentiment.vaderSentiment module.
# ----> 3 from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
#       4
#       5 # function to print sentiments
#
# ModuleNotFoundError: No module named 'vaderSentiment'

# %%
# 3) VADER via NTLK
# nltk.download('vader_lexicon')
neg_text ='great product!'
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

def vader_analyzer(doc):
    analyzer = SentimentIntensityAnalyzer()
    df = pd.DataFrame(columns=['Sentiment'])
    sentences = tokenize.sent_tokenize(doc)
    for i, sentence in enumerate(sentences):
        # returns neg, neu, pos, compound sentiment for each sentence token
        df = df.append({'Sentiment': analyzer.polarity_scores(sentence)['compound']}, ignore_index=True)
    return df

vader_neg = vader_analyzer(neg_text)
vader_pos = vader_analyzer(pos_text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19100\2911918102.py in <module>
#       2 # nltk.download('vader_lexicon')
#       3 neg_text ='great product!'
# ----> 4 from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
#       5
#       6 def vader_analyzer(doc):
#
# ModuleNotFoundError: No module named 'vaderSentiment'

# %%
import vaderSentiment
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19100\1649769433.py in <module>
# ----> 1 import vaderSentiment
#
# ModuleNotFoundError: No module named 'vaderSentiment'
